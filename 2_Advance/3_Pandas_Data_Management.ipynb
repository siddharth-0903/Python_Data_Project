# %%
#importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5, random_state=76)
# Out:
#              job_title_short                 job_title  \
# 721995         Data Engineer         Sr. Data Engineer
# 179568        Data Scientist  Data Scientist, Appstore
# 230998  Senior Data Engineer      Senior Data Engineer
# 367696          Data Analyst              Data Analyst
# 684564          Data Analyst              Data Analyst
#
#                       job_location          job_via job_schedule_type  \
# 721995             San Leandro, CA    via WANE Jobs         Full-time
# 179568  Chennai, Tamil Nadu, India       via Indeed         Full-time
# 230998                      Poland     via LinkedIn        Contractor
# 367696             Dublin, Ireland  via Recruit.net         Full-time
# 684564                   Hong Kong  via Trabajo.org         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 721995               False  Illinois, United States 2023-05-28 21:07:01
# 179568               False                    India 2023-10-27 15:09:58
# 230998               False                   Poland 2023-07-14 07:25:41
# 367696               False                  Ireland 2023-07-14 23:52:32
# 684564               False                Hong Kong 2023-07-29 10:20:00
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 721995                  False                 False  United States
# 179568                  False                 False          India
# 230998                  False                 False         Poland
# 367696                   True                 False        Ireland
# 684564                   True                 False      Hong Kong
#
#        salary_rate  salary_year_avg  salary_hour_avg           company_name  \
# 721995        year         151840.0              NaN               Supernal
# 179568        None              NaN              NaN        ADCI MAA 15 SEZ
# 230998        None              NaN              NaN        Work Life Group
# 367696        None              NaN              NaN                 Aspira
# 684564        None              NaN              NaN  Swing Consulting Ltd.
#
#                                                job_skills  \
# 721995  ['sql', 'snowflake', 'bigquery', 'aws', 'redsh...
# 179568  ['sql', 'python', 'r', 'sas', 'sas', 'matlab',...
# 230998             ['sql', 'sql server', 'azure', 'ssis']
# 367696                                               None
# 684564                              ['python', 'tableau']
#
#                                           job_type_skills
# 721995  {'cloud': ['snowflake', 'bigquery', 'aws', 're...
# 179568  {'analyst_tools': ['sas', 'tableau'], 'cloud':...
# 230998  {'analyst_tools': ['ssis'], 'cloud': ['azure']...
# 367696                                               None
# 684564  {'analyst_tools': ['tableau'], 'programming': ...

# %%
df_altered = df.copy()

# %%
median_salary = df_altered['salary_year_avg'].median()

# %%
df_altered['salary_year_avg']=df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64
